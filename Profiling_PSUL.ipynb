# %%
import pstats

# %%
p = pstats.Stats('/Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output1')
p.strip_dirs().sort_stats('time').print_stats(.1)
# Out:
# Mon Jun  2 14:35:02 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output1
#
#          112001724 function calls (111990903 primitive calls) in 519.897 seconds
#
#    Ordered by: internal time
#    List reduced from 2333 to 233 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1461  143.371    0.098  143.371    0.098 {built-in method do_handshake}
#      1464  122.174    0.083  122.174    0.083 {method 'connect' of '_socket.socket' objects}
#      2134  104.909    0.049  104.909    0.049 {built-in method read}
#  11572133   33.132    0.000   33.132    0.000 {method 'recv' of '_socket.socket' objects}
#   1942232   17.951    0.000  148.518    0.000 socket.py:406(readline)
#      1461   15.455    0.011   15.455    0.011 {_ssl.sslwrap}
#   3854115   10.745    0.000   33.234    0.000 socket.py:336(read)
#   3852689    8.973    0.000   45.508    0.000 httplib.py:637(_safe_read)
# ...

# %%
p.strip_dirs().sort_stats('cumtime').print_stats(.1)
# Out:
# Mon Jun  2 14:35:02 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output1
#
#          112001724 function calls (111990903 primitive calls) in 519.897 seconds
#
#    Ordered by: cumulative time
#    List reduced from 2333 to 233 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.005    0.005  520.004  520.004 project_summary_upload_LIMS.py:2(<module>)
#         1    0.000    0.000  519.534  519.534 project_summary_upload_LIMS.py:28(main)
#         1    0.001    0.001  515.194  515.194 objectsDB.py:35(__init__)
#        16    0.003    0.000  482.736   30.171 objectsDB.py:184(__init__)
#      1461    0.020    0.000  393.931    0.270 lims.py:47(get)
#      1461    0.033    0.000  393.032    0.269 api.py:47(get)
#      1461    0.023    0.000  392.998    0.269 api.py:17(request)
#      1461    0.068    0.000  392.553    0.269 sessions.py:291(request)
# ...

# %% [markdown]
# ## One more time to check for variation

# %%
p2 = pstats.Stats('/Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output2')
p2.strip_dirs().sort_stats('time').print_stats(.1)
# Out:
# Tue Jun  3 10:07:44 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output2
#
#          112014221 function calls (112003400 primitive calls) in 471.803 seconds
#
#    Ordered by: internal time
#    List reduced from 2333 to 233 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1464  134.717    0.092  134.717    0.092 {method 'connect' of '_socket.socket' objects}
#      1461  124.949    0.086  124.949    0.086 {built-in method do_handshake}
#      2134   94.454    0.044   94.454    0.044 {built-in method read}
#  11574584   29.580    0.000   29.580    0.000 {method 'recv' of '_socket.socket' objects}
#   1942232   14.821    0.000  130.692    0.000 socket.py:406(readline)
#      1461   12.382    0.008   12.382    0.008 {_ssl.sslwrap}
#   3854115    8.758    0.000   28.881    0.000 socket.py:336(read)
#   3852689    6.861    0.000   38.148    0.000 httplib.py:637(_safe_read)
# ...

# %%
p2.strip_dirs().sort_stats('cumtime').print_stats(.1)
# Out:
# Tue Jun  3 10:07:44 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output2
#
#          112014221 function calls (112003400 primitive calls) in 471.803 seconds
#
#    Ordered by: cumulative time
#    List reduced from 2333 to 233 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.004    0.004  471.885  471.885 project_summary_upload_LIMS.py:2(<module>)
#         1    0.000    0.000  470.108  470.108 project_summary_upload_LIMS.py:28(main)
#         1    0.001    0.001  468.792  468.792 objectsDB.py:35(__init__)
#        16    0.002    0.000  444.947   27.809 objectsDB.py:184(__init__)
#      1461    0.011    0.000  371.511    0.254 lims.py:47(get)
#      1461    0.023    0.000  370.792    0.254 api.py:47(get)
#      1461    0.015    0.000  370.769    0.254 api.py:17(request)
#      1461    0.039    0.000  370.474    0.254 sessions.py:291(request)
# ...

# %% [markdown]
# # Using a Session object for the lims http requests

# %%
p3 = pstats.Stats('/Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output3')
p3.strip_dirs().sort_stats('time').print_stats(.1)
# Out:
# Mon Jun  2 17:31:45 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output3
#
#          111571090 function calls (111548282 primitive calls) in 205.621 seconds
#
#    Ordered by: internal time
#    List reduced from 2351 to 235 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      3578  106.915    0.030  106.915    0.030 {built-in method read}
#  11572243   25.586    0.000   25.586    0.000 {method 'recv' of '_socket.socket' objects}
#   1941654   14.902    0.000  142.891    0.000 socket.py:406(readline)
#   3854113    8.630    0.000   25.130    0.000 socket.py:336(read)
#   3852685    6.622    0.000   34.178    0.000 httplib.py:637(_safe_read)
#       202    6.147    0.030   74.871    0.371 httplib.py:579(_read_chunked)
#   9666453    3.920    0.000    3.920    0.000 {method 'write' of 'cStringIO.StringO' objects}
# ...

# %%
p3.strip_dirs().sort_stats('cumtime').print_stats(.1)
# Out:
# Mon Jun  2 17:31:45 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output3
#
#          111571090 function calls (111548282 primitive calls) in 205.621 seconds
#
#    Ordered by: cumulative time
#    List reduced from 2351 to 235 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003  205.706  205.706 project_summary_upload_LIMS.py:2(<module>)
#         1    0.000    0.000  205.303  205.303 project_summary_upload_LIMS.py:28(main)
#         1    0.000    0.000  203.294  203.294 objectsDB.py:35(__init__)
#        16    0.002    0.000  194.516   12.157 objectsDB.py:184(__init__)
#   1941654   14.902    0.000  142.891    0.000 socket.py:406(readline)
#        16    0.566    0.035  116.833    7.302 objectsDB.py:241(get_sample_run_metrics)
#      1461    0.010    0.000  113.373    0.078 lims.py:49(get)
#      1461    0.010    0.000  112.644    0.077 sessions.py:387(get)
# ...

# %% [markdown]
# ## A second time using a session for keeping connections

# %%
p4 = pstats.Stats('/Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output4')
p4.strip_dirs().sort_stats('time').print_stats(.1)
# Out:
# Mon Jun  2 17:43:37 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output4
#
#          111570952 function calls (111548144 primitive calls) in 215.131 seconds
#
#    Ordered by: internal time
#    List reduced from 2351 to 235 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      3578  114.988    0.032  114.988    0.032 {built-in method read}
#  11572213   26.513    0.000   26.513    0.000 {method 'recv' of '_socket.socket' objects}
#   1941654   14.453    0.000  150.686    0.000 socket.py:406(readline)
#   3854113    8.232    0.000   24.899    0.000 socket.py:336(read)
#   3852685    6.497    0.000   33.692    0.000 httplib.py:637(_safe_read)
#       202    5.756    0.028   72.254    0.358 httplib.py:579(_read_chunked)
#   9666393    3.685    0.000    3.685    0.000 {method 'write' of 'cStringIO.StringO' objects}
#        15    3.288    0.219    3.288    0.219 {built-in method do_handshake}
# ...

# %%
p4.strip_dirs().sort_stats('cumtime').print_stats(.1)
# Out:
# Mon Jun  2 17:43:37 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output4
#
#          111570952 function calls (111548144 primitive calls) in 215.131 seconds
#
#    Ordered by: cumulative time
#    List reduced from 2351 to 235 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003  215.213  215.213 project_summary_upload_LIMS.py:2(<module>)
#         1    0.000    0.000  214.811  214.811 project_summary_upload_LIMS.py:28(main)
#         1    0.000    0.000  211.497  211.497 objectsDB.py:35(__init__)
#        16    0.002    0.000  202.348   12.647 objectsDB.py:184(__init__)
#   1941654   14.453    0.000  150.686    0.000 socket.py:406(readline)
#        16    0.542    0.034  127.024    7.939 objectsDB.py:241(get_sample_run_metrics)
#      1461    0.009    0.000  123.312    0.084 lims.py:49(get)
#      1461    0.010    0.000  122.594    0.084 sessions.py:387(get)
# ...

# %% [markdown]
# # Optimization 2; fetching processes per artifact outside loop

# %%
p5 = pstats.Stats('/Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output5')
p5.strip_dirs().sort_stats('time').print_stats(.1)
# Out:
# Tue Jun  3 14:13:52 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output5
#
#          112424335 function calls (112410468 primitive calls) in 114.979 seconds
#
#    Ordered by: internal time
#    List reduced from 2352 to 235 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1927   25.835    0.013   25.835    0.013 {built-in method read}
#  11572242   17.427    0.000   17.427    0.000 {method 'recv' of '_socket.socket' objects}
#   1933628   15.318    0.000   60.059    0.000 socket.py:406(readline)
#   3853269    8.573    0.000   19.061    0.000 socket.py:336(read)
#   3852650    6.719    0.000   28.225    0.000 httplib.py:637(_safe_read)
#       195    6.094    0.031   69.066    0.354 httplib.py:579(_read_chunked)
#   9655987    3.903    0.000    3.903    0.000 {method 'write' of 'cStringIO.StringO' objects}
#         1    2.936    2.936    2.936    2.936 {raw_input}
# ...

# %%
p5.strip_dirs().sort_stats('cumtime').print_stats(.1)
# Out:
# Tue Jun  3 14:13:52 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output5
#
#          112424335 function calls (112410468 primitive calls) in 114.979 seconds
#
#    Ordered by: cumulative time
#    List reduced from 2352 to 235 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.004    0.004  115.076  115.076 project_summary_upload_LIMS.py:2(<module>)
#         1    0.000    0.000  114.656  114.656 project_summary_upload_LIMS.py:28(main)
#         1    0.000    0.000  111.524  111.524 objectsDB.py:35(__init__)
#        16    0.002    0.000  103.092    6.443 objectsDB.py:210(__init__)
#        16    0.549    0.034   79.533    4.971 objectsDB.py:269(get_sample_run_metrics)
#        64    0.305    0.005   73.753    1.152 statusDB_utils.py:131(find_sample_run_id_from_view)
#        65    0.000    0.000   73.127    1.125 client.py:1156(__iter__)
# ...

# %% [markdown]
# ## Another time to estimate variability:

# %%
p6 = pstats.Stats('/Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output6')
p6.strip_dirs().sort_stats('time').print_stats(.1)
# Out:
# Tue Jun  3 14:19:05 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output6
#
#          112429006 function calls (112415139 primitive calls) in 114.726 seconds
#
#    Ordered by: internal time
#    List reduced from 2352 to 235 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1927   25.561    0.013   25.561    0.013 {built-in method read}
#  11572374   18.672    0.000   18.672    0.000 {method 'recv' of '_socket.socket' objects}
#   1933628   14.807    0.000   59.608    0.000 socket.py:406(readline)
#   3853269    8.702    0.000   20.234    0.000 socket.py:336(read)
#   3852650    6.756    0.000   29.440    0.000 httplib.py:637(_safe_read)
#       195    6.148    0.032   69.851    0.358 httplib.py:579(_read_chunked)
#   9656251    3.958    0.000    3.958    0.000 {method 'write' of 'cStringIO.StringO' objects}
# ...

# %%
p6.strip_dirs().sort_stats('cumtime').print_stats(.1)
# Out:
# Tue Jun  3 14:19:05 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output6
#
#          112429006 function calls (112415139 primitive calls) in 114.726 seconds
#
#    Ordered by: cumulative time
#    List reduced from 2352 to 235 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.008    0.008  114.831  114.831 project_summary_upload_LIMS.py:2(<module>)
#         1    0.000    0.000  114.406  114.406 project_summary_upload_LIMS.py:28(main)
#         1    0.000    0.000  112.791  112.791 objectsDB.py:35(__init__)
#        16    0.002    0.000  104.674    6.542 objectsDB.py:210(__init__)
#        16    0.588    0.037   80.992    5.062 objectsDB.py:269(get_sample_run_metrics)
#        64    0.321    0.005   74.979    1.172 statusDB_utils.py:131(find_sample_run_id_from_view)
#        65    0.000    0.000   74.328    1.144 client.py:1156(__iter__)
# ...

# %% [markdown]
# # Optimization 3: Change statusdb view for 'find_sample_run_id_from_view'

# %%
p17 = pstats.Stats('/Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output17')
p17.strip_dirs().sort_stats('time').print_stats(.1)
# Out:
# Wed Jun  4 14:28:03 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output17
#
#          14070235 function calls (14056370 primitive calls) in 68.118 seconds
#
#    Ordered by: internal time
#    List reduced from 2361 to 236 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1927   50.825    0.026   50.825    0.026 {built-in method read}
#     19837    3.464    0.000    3.464    0.000 {method 'recv' of '_socket.socket' objects}
#    292688    2.362    0.000    4.558    0.000 entities.py:438(get_dict)
#         1    1.485    1.485    1.485    1.485 {raw_input}
#         8    0.898    0.112    0.898    0.112 {built-in method do_handshake}
#    596749    0.793    0.000    2.210    0.000 ElementPath.py:283(find)
#   1133723    0.673    0.000    0.879    0.000 ElementPath.py:98(select)
#    600582    0.582    0.000    0.686    0.000 ElementPath.py:247(iterfind)
# ...

# %%
p17.strip_dirs().sort_stats('cumtime').print_stats(.1)
# Out:
# Wed Jun  4 14:28:03 2014    /Users/johannesalneberg/repos/scilifelab_profile/profiling_results/cprofile_output17
#
#          14070235 function calls (14056370 primitive calls) in 68.118 seconds
#
#    Ordered by: cumulative time
#    List reduced from 2361 to 236 due to restriction <0.1>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.004    0.004   68.212   68.212 project_summary_upload_LIMS.py:2(<module>)
#         1    0.000    0.000   67.796   67.796 project_summary_upload_LIMS.py:28(main)
#         1    0.000    0.000   66.127   66.127 objectsDB.py:35(__init__)
#        16    0.002    0.000   55.648    3.478 objectsDB.py:210(__init__)
#      8258    0.088    0.000   54.173    0.007 socket.py:406(readline)
#       659    0.004    0.000   54.137    0.082 lims.py:49(get)
#       659    0.004    0.000   53.631    0.081 sessions.py:387(get)
#       659    0.017    0.000   53.627    0.081 sessions.py:291(request)
# ...
