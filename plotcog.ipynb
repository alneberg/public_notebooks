# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import matplotlib as mpl
import pandas as pd
# %matplotlib inline

# %%
from collections import Counter

# %%
sns.set_context("poster")

# %%
cluster_assignments = pd.read_table("/Users/johannesalneberg/repos/public_notebooks/OTU_data/classification_result.tsv", index_col=0)
distribution_16S = pd.read_table("/Users/johannesalneberg/repos/public_notebooks/OTU_data/training_data/SMHI16S_150327_min300.tsv", index_col=0)
cog_functions = pd.read_table("/Users/johannesalneberg/repos/public_notebooks/OTU_data/cog_function.csv", sep=',', header=None, index_col=0, names=["cog_id", "category", "desc"])
cog_files = pd.read_table("/Users/johannesalneberg/repos/public_notebooks/OTU_data/cluster_to_cog.csv", sep=',', header=None, index_col=0, names=['cluster', 'cog_file'])
df_sample_info = pd.read_table("/Users/johannesalneberg/repos/public_notebooks/OTU_data/training_data/sample_info_transpaper_2013.tab", index_col=0)

# %%
DATA_LOC = "/Users/johannesalneberg/repos/public_notebooks/OTU_data"
cogs_per_cluster = {}
for cluster, row in cog_files.iterrows():
    cog_list = pd.Series.from_csv("{0}/cogs/{1}.cog".format(DATA_LOC, row['cog_file']), header=None, sep='\t').values
    cogs_per_cluster[cluster] = dict(Counter(cog_list))

cog_cluster_df = pd.DataFrame.from_dict(cogs_per_cluster)

# %%
cog_cluster_df.head()
# Out:
#          CLUSTER1  CLUSTER11  CLUSTER14  CLUSTER16  CLUSTER21  CLUSTER22  \
# COG0001         1        NaN          1          3        NaN          1
# COG0002         1        NaN          1          1        NaN          1
# COG0004         2        NaN          2          2          1          1
# COG0005       NaN        NaN          1        NaN          1          1
# COG0006         1          1          1          2          2          1
#
#          CLUSTER27  CLUSTER28  CLUSTER29  CLUSTER30  CLUSTER4  CLUSTER8  \
# COG0001          4          2        NaN        NaN         2         1
# COG0002        NaN          1          1          1         1         1
# COG0004          1          1          1          1         1         1
# COG0005          1          1        NaN          1         1         1
# COG0006          4        NaN          3          1       NaN         2
#
#          CLUSTER9
# COG0001         1
# COG0002         1
# COG0004         2
# ...

# %%
cog_cluster_df.ix['COG0385']
# Out:
# CLUSTER1    NaN
# CLUSTER11   NaN
# CLUSTER14   NaN
# CLUSTER16     1
# CLUSTER21   NaN
# CLUSTER22     1
# CLUSTER27   NaN
# CLUSTER28   NaN
# CLUSTER29   NaN
# CLUSTER30   NaN
# CLUSTER4    NaN
# CLUSTER8      1
# CLUSTER9    NaN
# Name: COG0385, dtype: float64

# %%
#Rhodopsin
cog_cluster_df.ix['COG5524']
# Out:
# CLUSTER1    NaN
# CLUSTER11   NaN
# CLUSTER14   NaN
# CLUSTER16   NaN
# CLUSTER21   NaN
# CLUSTER22   NaN
# CLUSTER27     1
# CLUSTER28   NaN
# CLUSTER29   NaN
# CLUSTER30   NaN
# CLUSTER4      1
# CLUSTER8    NaN
# CLUSTER9      1
# Name: COG5524, dtype: float64

# %%
E_cogs = cog_functions[cog_functions['category'].apply(lambda x: 'E' in x)].index
len(E_cogs)
# Out:
# 270

# %%
P_cogs = cog_functions[cog_functions['category'].apply(lambda x: 'P' in x)].index
len(P_cogs)
# Out:
# 212

# %%
all_cogs = cog_functions.index
len(all_cogs)
# Out:
# 4873

# %%
cluster_assignments.columns
# Out:
# Index([u'kingdom', u'2nd_largest', u'signal', u'class', u'phylum', u'largest', u'order', u'otu', u'otu_order', u'otu_kingdom', u'otu_phylum', u'otu_class'], dtype='object')

# %%
cluster_to_otu = {}
for cluster, otu in cluster_assignments['otu'].iteritems():
    cluster_to_otu[cluster] = otu

# %%
sample_cols = [x for x in distribution_16S.columns if x.startswith('SMHIFiltrated')]
sample_distribution_16S = distribution_16S[sample_cols]
sample_distribution_16S_norm = sample_distribution_16S.div(sample_distribution_16S.sum(axis=0))
sample_distribution_16S_norm.head()
# Out:
#        SMHIFiltrated16S1.uc  SMHIFiltrated16S10.uc  SMHIFiltrated16S11.uc  \
# OTU
# OTU_1              0.004573               0.017061               0.027370
# OTU_2              0.178628               0.021799               0.037859
# OTU_3              0.103782               0.008705               0.011702
# OTU_4              0.045471               0.003484               0.005721
# OTU_5              0.002726               0.000362               0.000542
#
#        SMHIFiltrated16S12.uc  SMHIFiltrated16S13.uc  SMHIFiltrated16S14.uc  \
# OTU
# OTU_1               0.008955               0.014946               0.010147
# OTU_2               0.129253               0.153786               0.102917
# OTU_3               0.016022               0.018005               0.147248
# OTU_4               0.010453               0.014417               0.016687
# OTU_5               0.000998               0.001407               0.004094
#
# ...

# %%
sample_distribution_16S_norm.sum(axis=0)
# Out:
# SMHIFiltrated16S1.uc     1
# SMHIFiltrated16S10.uc    1
# SMHIFiltrated16S11.uc    1
# SMHIFiltrated16S12.uc    1
# SMHIFiltrated16S13.uc    1
# SMHIFiltrated16S14.uc    1
# SMHIFiltrated16S15.uc    1
# SMHIFiltrated16S17.uc    1
# SMHIFiltrated16S18.uc    1
# SMHIFiltrated16S19.uc    1
# SMHIFiltrated16S2.uc     1
# SMHIFiltrated16S20.uc    1
# SMHIFiltrated16S21.uc    1
# SMHIFiltrated16S22.uc    1
# SMHIFiltrated16S3.uc     1
# SMHIFiltrated16S4.uc     1
# SMHIFiltrated16S5.uc     1
# SMHIFiltrated16S6.uc     1
# SMHIFiltrated16S7.uc     1
# SMHIFiltrated16S8.uc     1
# SMHIFiltrated16S9.uc     1
# dtype: float64

# %%
sample_name_to_nr = {}
for sample_name in sample_distribution_16S.columns:
    sample_name_to_nr[sample_name] = int(sample_name.replace("SMHIFiltrated16S", "").replace(".uc", ""))
sample_name_to_nr
# Out:
# {'SMHIFiltrated16S1.uc': 1,
#  'SMHIFiltrated16S10.uc': 10,
#  'SMHIFiltrated16S11.uc': 11,
#  'SMHIFiltrated16S12.uc': 12,
#  'SMHIFiltrated16S13.uc': 13,
#  'SMHIFiltrated16S14.uc': 14,
#  'SMHIFiltrated16S15.uc': 15,
#  'SMHIFiltrated16S17.uc': 17,
#  'SMHIFiltrated16S18.uc': 18,
#  'SMHIFiltrated16S19.uc': 19,
#  'SMHIFiltrated16S2.uc': 2,
#  'SMHIFiltrated16S20.uc': 20,
#  'SMHIFiltrated16S21.uc': 21,
#  'SMHIFiltrated16S22.uc': 22,
#  'SMHIFiltrated16S3.uc': 3,
#  'SMHIFiltrated16S4.uc': 4,
#  'SMHIFiltrated16S5.uc': 5,
#  'SMHIFiltrated16S6.uc': 6,
#  'SMHIFiltrated16S7.uc': 7,
#  'SMHIFiltrated16S8.uc': 8,
#  'SMHIFiltrated16S9.uc': 9}

# %%
plot_cogs = {'Rhodopsin': ['COG5524'], 'Amino Acid metabolism and transport': E_cogs, 'Inorganic ion transport': P_cogs, 'All COG:s': all_cogs}
data_d = {}
for title, cogs in plot_cogs.iteritems():
    per_cluster = cog_cluster_df.ix[cogs].sum()
    nonzero_clusters = per_cluster[per_cluster.notnull()]
    abundance_for_cogs = None
    for cluster, n in pd.Series(nonzero_clusters).iteritems():
        otu = cluster_to_otu[cluster]
        if abundance_for_cogs is None:
            abundance_for_cogs = int(n)*sample_distribution_16S_norm.ix[otu]
        else:
            abundance_for_cogs += int(n)*sample_distribution_16S_norm.ix[otu]
    data_d[title] = abundance_for_cogs

# Add a null model corresponding to a cog present once in each genome
all_nonzero_clusters = cog_cluster_df.columns
abundance_for_cogs = None
for cluster in all_nonzero_clusters:
    otu = cluster_to_otu[cluster]
    if abundance_for_cogs is None:
        abundance_for_cogs = sample_distribution_16S_norm.ix[otu]
    else:
        abundance_for_cogs += sample_distribution_16S_norm.ix[otu]

data_d['Null Model'] = abundance_for_cogs
sample_nr = [sample_name_to_nr[x] for x in abundance_for_cogs.index]
data_d['Salinity'] = df_sample_info.ix[sample_nr]['Salinity'].values
data_df = pd.DataFrame(data_d)
data_df = data_df.sort('Salinity')
data_df
# Out:
#                         All COG:s  Amino Acid metabolism and transport  \
# SMHIFiltrated16S10.uc  104.009851                            13.820483
# SMHIFiltrated16S11.uc  105.316806                            13.769726
# SMHIFiltrated16S9.uc   121.800972                            15.757903
# SMHIFiltrated16S12.uc  161.403173                            21.353609
# SMHIFiltrated16S13.uc  145.484654                            18.740068
# SMHIFiltrated16S8.uc   232.677656                            27.784612
# SMHIFiltrated16S7.uc   231.317411                            26.869547
# SMHIFiltrated16S6.uc   231.394904                            27.655878
# SMHIFiltrated16S14.uc  283.451149                            33.233668
# SMHIFiltrated16S5.uc   237.948956                            27.256623
# SMHIFiltrated16S15.uc  247.762222                            28.548306
# SMHIFiltrated16S17.uc  212.565839                            24.002569
# ...

# %%
"""
Example of creating a radar chart (a.k.a. a spider or star chart) [1]_.

Although this example allows a frame of either 'circle' or 'polygon', polygon
frames don't have proper gridlines (the lines are circles instead of polygons).
It's possible to get a polygon grid by setting GRIDLINE_INTERPOLATION_STEPS in
matplotlib.axis to the desired number of vertices, but the orientation of the
polygon is not aligned with the radial axes.

.. [1] http://en.wikipedia.org/wiki/Radar_chart
"""
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.projections.polar import PolarAxes
from matplotlib.projections import register_projection


def radar_factory(num_vars, frame='circle'):
    """Create a radar chart with `num_vars` axes.

    This function creates a RadarAxes projection and registers it.

    Parameters
    ----------
    num_vars : int
        Number of variables for radar chart.
    frame : {'circle' | 'polygon'}
        Shape of frame surrounding axes.

    """
    # calculate evenly-spaced axis angles
    theta = 2*np.pi * np.linspace(0, 1-1./num_vars, num_vars)
    # rotate theta such that the first axis is at the top
    theta += np.pi/2

    def draw_poly_patch(self):
        verts = unit_poly_verts(theta)
        return plt.Polygon(verts, closed=True, edgecolor='k')

    def draw_circle_patch(self):
        # unit circle centered on (0.5, 0.5)
        return plt.Circle((0.5, 0.5), 0.5)

    patch_dict = {'polygon': draw_poly_patch, 'circle': draw_circle_patch}
    if frame not in patch_dict:
        raise ValueError('unknown value for `frame`: %s' % frame)

    class RadarAxes(PolarAxes):

        name = 'radar'
        # use 1 line segment to connect specified points
        RESOLUTION = 1
        # define draw_frame method
        draw_patch = patch_dict[frame]

        def fill(self, *args, **kwargs):
            """Override fill so that line is closed by default"""
            closed = kwargs.pop('closed', True)
            return super(RadarAxes, self).fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            """Override plot so that line is closed by default"""
            lines = super(RadarAxes, self).plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            # FIXME: markers at x[0], y[0] get doubled-up
            if x[0] != x[-1]:
                x = np.concatenate((x, [x[0]]))
                y = np.concatenate((y, [y[0]]))
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(theta * 180/np.pi, labels)

        def _gen_axes_patch(self):
            return self.draw_patch()

        def _gen_axes_spines(self):
            if frame == 'circle':
                return PolarAxes._gen_axes_spines(self)
            # The following is a hack to get the spines (i.e. the axes frame)
            # to draw correctly for a polygon frame.

            # spine_type must be 'left', 'right', 'top', 'bottom', or `circle`.
            spine_type = 'circle'
            verts = unit_poly_verts(theta)
            # close off polygon by repeating first vertex
            verts.append(verts[0])
            path = Path(verts)

            spine = Spine(self, spine_type, path)
            spine.set_transform(self.transAxes)
            return {'polar': spine}

    register_projection(RadarAxes)
    return theta


def unit_poly_verts(theta):
    """Return vertices of polygon for subplot axes.

    This polygon is circumscribed by a unit circle centered at (0.5, 0.5)
    """
    x0, y0, r = [0.5] * 3
    verts = [(r*np.cos(t) + x0, r*np.sin(t) + y0) for t in theta]
    return verts


def example_data():
    #The following data is from the Denver Aerosol Sources and Health study.
    #See  doi:10.1016/j.atmosenv.2008.12.017
    #
    #The data are pollution source profile estimates for five modeled pollution
    #sources (e.g., cars, wood-burning, etc) that emit 7-9 chemical species.
    #The radar charts are experimented with here to see if we can nicely
    #visualize how the modeled source profiles change across four scenarios:
    #  1) No gas-phase species present, just seven particulate counts on
    #     Sulfate
    #     Nitrate
    #     Elemental Carbon (EC)
    #     Organic Carbon fraction 1 (OC)
    #     Organic Carbon fraction 2 (OC2)
    #     Organic Carbon fraction 3 (OC3)
    #     Pyrolized Organic Carbon (OP)
    #  2)Inclusion of gas-phase specie carbon monoxide (CO)
    #  3)Inclusion of gas-phase specie ozone (O3).
    #  4)Inclusion of both gas-phase speciesis present...
    data = {
        'column names':
            ['Sulfate', 'Nitrate', 'EC', 'OC1', 'OC2', 'OC3', 'OP', 'CO',
             'O3'],
        'Basecase':
            [[0.88, 0.01, 0.03, 0.03, 0.00, 0.06, 0.01, 0.00, 0.00],
             [0.07, 0.95, 0.04, 0.05, 0.00, 0.02, 0.01, 0.00, 0.00],
             [0.01, 0.02, 0.85, 0.19, 0.05, 0.10, 0.00, 0.00, 0.00],
             [0.02, 0.01, 0.07, 0.01, 0.21, 0.12, 0.98, 0.00, 0.00],
             [0.01, 0.01, 0.02, 0.71, 0.74, 0.70, 0.00, 0.00, 0.00]],
        'With CO':
            [[0.88, 0.02, 0.02, 0.02, 0.00, 0.05, 0.00, 0.05, 0.00],
             [0.08, 0.94, 0.04, 0.02, 0.00, 0.01, 0.12, 0.04, 0.00],
             [0.01, 0.01, 0.79, 0.10, 0.00, 0.05, 0.00, 0.31, 0.00],
             [0.00, 0.02, 0.03, 0.38, 0.31, 0.31, 0.00, 0.59, 0.00],
             [0.02, 0.02, 0.11, 0.47, 0.69, 0.58, 0.88, 0.00, 0.00]],
        'With O3':
            [[0.89, 0.01, 0.07, 0.00, 0.00, 0.05, 0.00, 0.00, 0.03],
             [0.07, 0.95, 0.05, 0.04, 0.00, 0.02, 0.12, 0.00, 0.00],
             [0.01, 0.02, 0.86, 0.27, 0.16, 0.19, 0.00, 0.00, 0.00],
             [0.01, 0.03, 0.00, 0.32, 0.29, 0.27, 0.00, 0.00, 0.95],
             [0.02, 0.00, 0.03, 0.37, 0.56, 0.47, 0.87, 0.00, 0.00]],
        'CO & O3':
            [[0.87, 0.01, 0.08, 0.00, 0.00, 0.04, 0.00, 0.00, 0.01],
             [0.09, 0.95, 0.02, 0.03, 0.00, 0.01, 0.13, 0.06, 0.00],
             [0.01, 0.02, 0.71, 0.24, 0.13, 0.16, 0.00, 0.50, 0.00],
             [0.01, 0.03, 0.00, 0.28, 0.24, 0.23, 0.00, 0.44, 0.88],
             [0.02, 0.00, 0.18, 0.45, 0.64, 0.55, 0.86, 0.00, 0.16]]}
    return data

# %%
if True:
    N = 9
    theta = radar_factory(N, frame='polygon')

    data = example_data()
    spoke_labels = data.pop('column names')

    fig = plt.figure(figsize=(9, 9))
    fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

    colors = ['b', 'r', 'g', 'm', 'y']
    # Plot the four cases from the example data on separate axes
    for n, title in enumerate(data.keys()):
        ax = fig.add_subplot(2, 2, n+1, projection='radar')
        plt.rgrids([0.2, 0.4, 0.6, 0.8])
        ax.set_title(title, weight='bold', size='medium', position=(0.5, 1.1),
                     horizontalalignment='center', verticalalignment='center')
        for d, color in zip(data[title], colors):
            ax.plot(theta, d, color=color)
            ax.fill(theta, d, facecolor=color, alpha=0.25)
        ax.set_varlabels(spoke_labels)

    # add legend relative to top-left plot
    plt.subplot(2, 2, 1)
    labels = ('Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5')
    legend = plt.legend(labels, loc=(0.9, .95), labelspacing=0.1)
    plt.setp(legend.get_texts(), fontsize='small')

    plt.figtext(0.5, 0.965, '5-Factor Solution Profiles Across Four Scenarios',
                ha='center', color='black', weight='bold', size='large')
    plt.show()

# %%
theta
# Out:
# array([ 1.57079633,  2.26892803,  2.96705973,  3.66519143,  4.36332313,
#         5.06145483,  5.75958653,  6.45771823,  7.15584993])

# %%
a = np.array(data_df['Rhodopsin'].values)
a
# Out:
# array([7440, 4057, 7497, 8625, 9105, 5712, 4146, 7098, 4475, 2907, 2836,
#        1438, 2179, 1596, 1107,  169, 1750, 2139, 1795,   13,    5])

# %%
sns.set_context("poster")

# %%
titles = ['Rhodopsin', 'Inorganic ion transport', 'All COG:s', 'Null Model']
N = len(data_df.index)
theta = radar_factory(N, frame='polygon')
spoke_labels = data_df['Salinity'].values
fig = plt.figure()
ax = plt.axes(projection='radar')
colors = [mpl.colors.rgb2hex(c) for c in sns.color_palette("colorblind")]
#fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)
title="Relative Occurrence over Salinity"
t = ax.set_title(title, loc="center")
t.set_y(1.08) 
for i, title in enumerate(titles):
    color = colors[i]
    d = data_df[title].values / float(data_df[title].values.sum())
    ax.plot(theta, d, color=color)
    ax.fill(theta, d, facecolor=color, alpha=0.25)
    ax.set_varlabels(spoke_labels)
        
ax.set_yticklabels([])
        
# add legend relative to top-left plot
plt.subplot(1, 1, 1)
legend = plt.legend(titles, loc=(0.9, .95), labelspacing=0.1)

plt.savefig("/Users/johannesalneberg/repos/public_notebooks/OTU_data/figures/cog_radar.png")

# %%
plt.savefig?
