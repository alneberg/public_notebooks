# %%
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %matplotlib inline

# %%
sns.set_context('talk')

# %%
usage = pd.read_table("uppmax_data/20170621.tsv", index_col=0, names=["cluster", "jobstate", "user", 
                                                                      "project", "job_name", "endtime", 
                                                                      "runtime", "flags", "booked", 
                                                                      "cores", "node", "jobstats"])

# %%
def runtime_to_minutes(runtime_s):
    if '-' in runtime_s:
        try:
            days_s, hours_s = runtime_s.split('-')
            days = int(days_s)
        except ValueError:
            print runtime_s
            raise
    else:
        days = 0
        hours_s = runtime_s
    hours, minutes, seconds = (int(x) for x in hours_s.split(':'))
    return (days*24+hours)*60 + minutes

# %%
usage['runtime_minutes'] = usage.runtime.apply(runtime_to_minutes)
usage['cpu_minutes'] = usage['runtime_minutes'] * usage['booked']

# %%
minutes_stats = {}
minutes_stats['no_flags'] = usage[usage['flags'] =='.'].cpu_minutes.sum()
minutes_stats['fat_node_flag_only'] = usage[usage['flags'] == 'node_type_overbooked:mem512GB:mem256GB'].cpu_minutes.sum() + \
    usage[usage['flags'] == 'node_type_overbooked:mem512GB:mem128GB'].cpu_minutes.sum() + \
    usage[usage['flags'] == 'node_type_overbooked:mem256GB:mem128GB'].cpu_minutes.sum()
minutes_stats['other_overbooked'] = usage[usage['flags'] !='.'].cpu_minutes.sum() - minutes_stats['fat_node_flag_only']

# %% [markdown]
# ## Proportion of efficiently running jobs
# Jobs that are flagged with using a fat node, when a thin node would have worked are not considered wasteful since there is normally no less access to fat nodes than thin nodes.

# %%
ax = pd.Series(minutes_stats).plot(kind='pie', figsize=(6,6), autopct='%.2f', fontsize=18, labels=["Fat node overbooked only", "No flags", "Other overbooked"])
t = ax.set_title("Percentage of CPU time over different flags")

# %%
usage_other_overbooked = usage[(usage['flags'] != '.') & ~(usage['flags'].isin(['node_type_overbooked:mem512GB:mem256GB',
                                                                                'node_type_overbooked:mem512GB:mem128GB',
                                                                                'node_type_overbooked:mem256GB:mem128GB',
                                                                                '!!swap_used']))]

# %% [markdown]
# ## Finding the worst offending jobs
# Jobs which were overbooked that used the most cpu time

# %%
usage_other_overbooked.sort('cpu_minutes', ascending=False).head(100)[['flags','user','job_name', 'cpu_minutes']]
# Out:
# /Users/johannesalneberg/anaconda/envs/basic_sandbox/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                       flags      user  \
# 10480826  overbooked:0%,!!half_overbooked,!!severely_ove...  alneberg
# 10368003  overbooked:62%,node_type_overbooked:mem512GB:m...  alneberg
# 10367996  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10367998  overbooked:38%,!!half_overbooked,node_type_ove...  alneberg
# 10426257  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# 10426228  overbooked:56%,node_type_overbooked:mem256GB:m...  alneberg
# 10436052  overbooked:44%,!!half_overbooked,node_type_ove...  alneberg
# 10367994  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# 10368004  overbooked:50%,node_type_overbooked:mem512GB:m...  alneberg
# 10367991  overbooked:44%,!!half_overbooked,node_type_ove...  alneberg
# 10367993  overbooked:38%,!!half_overbooked,node_type_ove...  alneberg
# 10368000  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# 10436050  overbooked:44%,!!half_overbooked,node_type_ove...  alneberg
# 10426238  overbooked:44%,!!half_overbooked,node_type_ove...  alneberg
# 10426239  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# 10426236  overbooked:38%,!!half_overbooked,node_type_ove...  alneberg
# 10367989  overbooked:44%,!!half_overbooked,node_type_ove...  alneberg
# 10436051  overbooked:44%,!!half_overbooked,cores_overboo...  alneberg
# 10533191  overbooked:25%,!!half_overbooked,cores_overboo...  alneberg
# 10426247  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# 10426227  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10426241  overbooked:38%,!!half_overbooked,node_type_ove...  alneberg
# 10426253  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10480811  overbooked:44%,!!half_overbooked,node_type_ove...  alneberg
# 10426263  overbooked:38%,!!half_overbooked,node_type_ove...  alneberg
# 10368001  overbooked:38%,!!half_overbooked,node_type_ove...  alneberg
# 10368002  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10426242  overbooked:44%,!!half_overbooked,node_type_ove...  alneberg
# 10426244  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# 10367980  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# ...                                                     ...       ...
# 10480777  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10480770  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10549687  overbooked:44%,!!half_overbooked,node_type_ove...  emmabell
# 10480782  overbooked:44%,!!half_overbooked,node_type_ove...  alneberg
# 10480784  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10480840  overbooked:19%,!!half_overbooked,!!severely_ov...  alneberg
# 10480844  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# 10480830  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10480795  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10480820  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# 10480812  overbooked:19%,!!half_overbooked,!!severely_ov...  alneberg
# 10549686  overbooked:38%,!!half_overbooked,node_type_ove...  emmabell
# 10480838  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# 10480773  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10480780  overbooked:38%,!!half_overbooked,node_type_ove...  alneberg
# 10480805  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10480829  overbooked:26%,!!half_overbooked,cores_overboo...  alneberg
# 10480768  overbooked:19%,!!half_overbooked,!!severely_ov...  alneberg
# 10480823  overbooked:19%,!!half_overbooked,!!severely_ov...  alneberg
# 10480776  overbooked:38%,!!half_overbooked,node_type_ove...  alneberg
# 10480818  overbooked:31%,!!half_overbooked,node_type_ove...  alneberg
# 10480837  overbooked:44%,!!half_overbooked,cores_overboo...  alneberg
# 10480815  overbooked:19%,!!half_overbooked,!!severely_ov...  alneberg
# 10480802  overbooked:25%,!!half_overbooked,node_type_ove...  alneberg
# 10524358  overbooked:19%,!!half_overbooked,!!severely_ov...  alneberg
# 10534707  overbooked:38%,!!half_overbooked,cores_overboo...  alneberg
# 10549689  overbooked:38%,!!half_overbooked,node_type_ove...  emmabell
# 10426240  overbooked:50%,node_type_overbooked:mem512GB:m...  alneberg
# 10426291                overbooked:67%,cores_overbooked:3:2  alneberg
# 10426267                overbooked:67%,cores_overbooked:3:2  alneberg
#
#                                               job_name  cpu_minutes
# 10480826            'snakemake_remove_mark_duplicates'        23040
# 10368003            'snakemake_remove_mark_duplicates'         5664
# 10367996            'snakemake_remove_mark_duplicates'         5632
# 10367998            'snakemake_remove_mark_duplicates'         5008
# 10426257            'snakemake_remove_mark_duplicates'         4960
# 10426228            'snakemake_remove_mark_duplicates'         4832
# 10436052            'snakemake_remove_mark_duplicates'         4656
# 10367994            'snakemake_remove_mark_duplicates'         4608
# 10368004            'snakemake_remove_mark_duplicates'         4608
# 10367991            'snakemake_remove_mark_duplicates'         4448
# 10367993            'snakemake_remove_mark_duplicates'         4224
# 10368000            'snakemake_remove_mark_duplicates'         4192
# 10436050            'snakemake_remove_mark_duplicates'         4176
# 10426238            'snakemake_remove_mark_duplicates'         4128
# 10426239            'snakemake_remove_mark_duplicates'         4128
# 10426236            'snakemake_remove_mark_duplicates'         4016
# 10367989            'snakemake_remove_mark_duplicates'         3904
# 10436051            'snakemake_remove_mark_duplicates'         3872
# 10533191                                  'sbatch_job'         3840
# 10426247            'snakemake_remove_mark_duplicates'         3696
# 10426227            'snakemake_remove_mark_duplicates'         3680
# 10426241            'snakemake_remove_mark_duplicates'         3680
# 10426253            'snakemake_remove_mark_duplicates'         3648
# 10480811            'snakemake_remove_mark_duplicates'         3632
# 10426263            'snakemake_remove_mark_duplicates'         3632
# 10368001            'snakemake_remove_mark_duplicates'         3616
# 10368002            'snakemake_remove_mark_duplicates'         3536
# 10426242            'snakemake_remove_mark_duplicates'         3504
# 10426244            'snakemake_remove_mark_duplicates'         3504
# 10367980            'snakemake_remove_mark_duplicates'         3456
# ...                                                ...          ...
# 10480777            'snakemake_remove_mark_duplicates'         1568
# 10480770            'snakemake_remove_mark_duplicates'         1568
# 10549687                          'snakemake_fastuniq'         1504
# 10480782            'snakemake_remove_mark_duplicates'         1488
# 10480784            'snakemake_remove_mark_duplicates'         1488
# 10480840            'snakemake_remove_mark_duplicates'         1456
# 10480844            'snakemake_remove_mark_duplicates'         1424
# 10480830            'snakemake_remove_mark_duplicates'         1376
# 10480795            'snakemake_remove_mark_duplicates'         1344
# 10480820            'snakemake_remove_mark_duplicates'         1312
# 10480812            'snakemake_remove_mark_duplicates'         1296
# 10549686                          'snakemake_fastuniq'         1264
# 10480838            'snakemake_remove_mark_duplicates'         1248
# 10480773            'snakemake_remove_mark_duplicates'         1200
# 10480780            'snakemake_remove_mark_duplicates'         1168
# 10480805            'snakemake_remove_mark_duplicates'         1120
# 10480829            'snakemake_remove_mark_duplicates'         1072
# 10480768            'snakemake_remove_mark_duplicates'         1040
# 10480823            'snakemake_remove_mark_duplicates'         1024
# 10480776            'snakemake_remove_mark_duplicates'         1024
# 10480818            'snakemake_remove_mark_duplicates'         1008
# 10480837            'snakemake_remove_mark_duplicates'          976
# 10480815            'snakemake_remove_mark_duplicates'          960
# 10480802            'snakemake_remove_mark_duplicates'          960
# 10524358                                  'sbatch_job'          960
# 10534707                                  'sbatch_job'          960
# 10549689                          'snakemake_fastuniq'          896
# 10426240            'snakemake_remove_mark_duplicates'          880
# 10426291  'snakemake_bowtie2_quant_genes_htseq_counts'          669
# 10426267  'snakemake_bowtie2_quant_genes_htseq_counts'          624
#
# [100 rows x 4 columns]

# %%
usage.cpu_minutes.sum()
# Out:
# 523675

# %%
usage_other_overbooked.cpu_minutes.sum()
# Out:
# 323670

# %%
usage_other_overbooked[usage_other_overbooked.job_name == 'snakemake_remove_mark_duplicates'].cpu_minutes.sum()
# Out:
# 0

# %%
usage_other_overbooked[usage_other_overbooked.job_name == 'snakemake_remove_mark_duplicates']
# Out:
# Empty DataFrame
# Columns: [cluster, jobstate, user, project, job_name, endtime, runtime, flags, booked, cores, node, jobstats, runtime_minutes, cpu_minutes]
# Index: []

# %%
usage_other_overbooked[['job_name', 'cpu_minutes']].groupby('job_name').sum()
# Out:
#                                                     cpu_minutes
# job_name
# '_interactive'                                              510
# 'gvcf_test'                                                   0
# 'sbatch_job'                                               6304
# 'snakemake_bam_sort'                                       6496
# 'snakemake_bam_sort_name'                                 10640
# 'snakemake_bedtools_coverage'                                16
# 'snakemake_bowtie2_map'                                      32
# 'snakemake_bowtie2_map_large'                                 0
# 'snakemake_bowtie2_quant_coverage_annotation_ta...           21
# 'snakemake_bowtie2_quant_genes_htseq_counts'              19434
# 'snakemake_bowtie2_raw_counts_gene_table'                    88
# 'snakemake_bowtie2_tpm_gene_table'                          856
# 'snakemake_concoct_generate_coverage_table_10K'              32
# 'snakemake_fastuniq'                                       9408
# 'snakemake_kallisto_index'                                   32
# 'snakemake_kallisto_quant_sample'                           544
# 'snakemake_remove_mark_duplicates'                       269200
# 'snakemake_sample_merge_no_rmdup'                            57
